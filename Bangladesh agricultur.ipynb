# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('Agricultural Dataset.csv')

# %%
df.head(10)
# Out:
#       District  year  area  avg_rainfall  max_temperature  min_temperature  \
# 0        dhaka  2008   NaN          2385            34.20            12.50
# 1      gazipur  2008   NaN          2197            30.20            19.50
# 2    narsingdi  2008   NaN          2197            34.20            12.50
# 3  narayangonj  2008   NaN          2197            34.20            12.20
# 4      tangail  2008   NaN          1856            34.10            10.20
# 5   mymenshing  2008   NaN          2239            29.60            21.60
# 6  kishoregonj  2008   NaN          2235            34.12            10.80
# 7        dhaka  2009   NaN          1930            35.60            14.80
# 8      gazipur  2009   NaN          1912            31.00            11.43
# 9    narsingdi  2009   NaN          1912            35.60            14.80
#
#      aus    aman    boro  wheat  ...  Noncalcareous Brown Floodplain Soil  \
# ...

# %%
#df.describe()

# %%
#df.info()

# %%
df = df.set_index('year')

# %%
df.head(10)
# Out:
#          District  area  avg_rainfall  max_temperature  min_temperature  \
# year
# 2008        dhaka   NaN          2385            34.20            12.50
# 2008      gazipur   NaN          2197            30.20            19.50
# 2008    narsingdi   NaN          2197            34.20            12.50
# 2008  narayangonj   NaN          2197            34.20            12.20
# 2008      tangail   NaN          1856            34.10            10.20
# 2008   mymenshing   NaN          2239            29.60            21.60
# 2008  kishoregonj   NaN          2235            34.12            10.80
# 2009        dhaka   NaN          1930            35.60            14.80
# 2009      gazipur   NaN          1912            31.00            11.43
# 2009    narsingdi   NaN          1912            35.60            14.80
#
#         aus    aman    boro  wheat  potato  ...  \
# year                                        ...
# 2008    804    9691  233939   1129   33679  ...
# ...

# %%
fp=df.pivot_table(index='year',columns='District',values='aus')
fp.head(12)
# Out:
# District  dhaka  gazipur  kishoregonj  mymenshing  narayangonj  narsingdi  \
# year
# 2008        804     4328        25072       88198         1617        484
# 2009       1492     4199        33845      106457         1591        530
# 2010       1353     4086        33830       71548         2220        516
# 2011        912     3869        45441      103901         1003        517
# 2012        927     4103        46162      108383          383        609
# 2013        752     3730        41550       75085          328        493
# 2014        948     6324        47548       63482          344        419
# 2015       1413     4071        45640       62927           49        474
# 2016       1431     2508        48583       57140          327        206
# 2017       1407     2980        45890       51783          288        565
#
# District  tangail
# year
# 2008          447
# 2009         1163
# 2010          907
# 2011          865
# 2012         1004
# 2013          709
# ...

# %%
fp=df.pivot_table(index='year',columns='District',values='boro')
fp.head(12)
# Out:
# District   dhaka  gazipur  kishoregonj  mymenshing  narayangonj  narsingdi  \
# year
# 2008      233939   208434       679546      812189       129390     207669
# 2009      217990   217819       679655      801190       118218     212482
# 2010      203305   247999       621424      908157       111879     229264
# 2011      226879   220675      1388619      925937       118127     223980
# 2012      204100   250778      1343510      966869       125444     220941
# 2013      190646   237235      1425741      936015       119076     228106
# 2014      200560   228161       707864     1076409       117576     205812
# 2015      205638   231718       713696     1080151       101838     196927
# 2016      211933   234186       699047     1074189        95582     197940
# 2017      218997   223605       503363     1072834        99814     190769
#
# District  tangail
# year
# 2008       672851
# 2009       637268
# 2010       645116
# 2011       652732
# 2012       658508
# ...

# %%
df.head()
# Out:
#       District  year  area  avg_rainfall  max_temperature  min_temperature  \
# 0        dhaka  2008   NaN          2385             34.2             12.5
# 1      gazipur  2008   NaN          2197             30.2             19.5
# 2    narsingdi  2008   NaN          2197             34.2             12.5
# 3  narayangonj  2008   NaN          2197             34.2             12.2
# 4      tangail  2008   NaN          1856             34.1             10.2
#
#     aus    aman    boro  wheat  ...  Noncalcareous Brown Floodplain Soil  \
# 0   804    9691  233939   1129  ...                                    0
# 1  4328   93956  208434    479  ...                                   13
# 2   484   93958  207669   2073  ...                                    0
# 3  1617   14485  129390   4585  ...                                    0
# 4   447  170918  672851  17477  ...                                  566
#
#    Shallow Red-Brown Terrace Soil  Deep Red-Brown Terrace Soil  \
# ...

# %%
sns.countplot(x='District', data=df, palette='viridis')

plt.xlabel('District')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')
